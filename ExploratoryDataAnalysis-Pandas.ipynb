# %%
#This is a raw Sales dataset, on which i will be performoing data cleaning

# %%
import pandas as pd

# %%
#reading the data from the file
df = pd.read_csv(r"/Users/shivakruthi/Downloads/dirty_cafe_sales.csv")

# %%
#this calls the data in the file
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#removing duplicates from the data set and saving it
df = df.drop_duplicates()
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#trying to unnecessary values at the end of the data

# %%
#replacing NaN values with empty value
df=df.fillna('')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401                  3                        3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3                        3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#replacing UNKNOWN values with empty value
df = df.replace('UNKNOWN', '')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401                  3                        3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3                        3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#replacing ERROR values with empty value
df = df.replace('ERROR', '')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401                  3                        3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3                        3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#replacing Nan values in the ITEM column with unknown value
df['Item'] = df['Item'].replace('','Unknown')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401   Unknown        3                        3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3                        3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#Converting values in Quantity column to Numeric/int
df['Quantity'] = pd.to_numeric(df['Quantity'])
df
# Out:
#      Transaction ID      Item  Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee       2.0            2.0         4.0
# 1       TXN_4977031      Cake       4.0            3.0        12.0
# 2       TXN_4271903    Cookie       4.0            1.0
# 3       TXN_7034554     Salad       2.0            5.0        10.0
# 4       TXN_3160411    Coffee       2.0            2.0         4.0
# ...             ...       ...       ...            ...         ...
# 9995    TXN_7672686    Coffee       2.0            2.0         4.0
# 9996    TXN_9659401   Unknown       3.0                        3.0
# 9997    TXN_5255387    Coffee       4.0            2.0         8.0
# 9998    TXN_7695629    Cookie       3.0                        3.0
# 9999    TXN_6170729  Sandwich       3.0            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#filling missing values in quantity with median
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())
df
# Out:
#      Transaction ID      Item  Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee       2.0            2.0         4.0
# 1       TXN_4977031      Cake       4.0            3.0        12.0
# 2       TXN_4271903    Cookie       4.0            1.0
# 3       TXN_7034554     Salad       2.0            5.0        10.0
# 4       TXN_3160411    Coffee       2.0            2.0         4.0
# ...             ...       ...       ...            ...         ...
# 9995    TXN_7672686    Coffee       2.0            2.0         4.0
# 9996    TXN_9659401   Unknown       3.0                        3.0
# 9997    TXN_5255387    Coffee       4.0            2.0         8.0
# 9998    TXN_7695629    Cookie       3.0                        3.0
# 9999    TXN_6170729  Sandwich       3.0            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#Converting values in Price per Unit column to Numeric/int
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'])
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0         4.0
# 1       TXN_4977031      Cake       4.0             3.0        12.0
# 2       TXN_4271903    Cookie       4.0             1.0
# 3       TXN_7034554     Salad       2.0             5.0        10.0
# 4       TXN_3160411    Coffee       2.0             2.0         4.0
# ...             ...       ...       ...             ...         ...
# 9995    TXN_7672686    Coffee       2.0             2.0         4.0
# 9996    TXN_9659401   Unknown       3.0             NaN         3.0
# 9997    TXN_5255387    Coffee       4.0             2.0         8.0
# 9998    TXN_7695629    Cookie       3.0             NaN         3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#filling missing values in Price with median
df['Price Per Unit'] = df['Price Per Unit'].fillna(df['Price Per Unit'].median())
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0         4.0
# 1       TXN_4977031      Cake       4.0             3.0        12.0
# 2       TXN_4271903    Cookie       4.0             1.0
# 3       TXN_7034554     Salad       2.0             5.0        10.0
# 4       TXN_3160411    Coffee       2.0             2.0         4.0
# ...             ...       ...       ...             ...         ...
# 9995    TXN_7672686    Coffee       2.0             2.0         4.0
# 9996    TXN_9659401   Unknown       3.0             3.0         3.0
# 9997    TXN_5255387    Coffee       4.0             2.0         8.0
# 9998    TXN_7695629    Cookie       3.0             3.0         3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#Converting values in Total Spent column to Numeric/int
df['Total Spent'] = pd.to_numeric(df['Total Spent'])
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          NaN
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
#filling missing values in Total using formulae
#total= Quantity* Price Per Unit
#total

# %%
df['Total Spent'] = df['Total Spent'].fillna(df['Total Spent'].median())
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
#replacing empty values in the Payment method column with unknown value
df['Payment Method'] = df['Payment Method'].replace('','Unknown')
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
#replacing empty values in the Location column with unknown value
df['Location'] = df['Location'].replace('','Unknown')
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
#verifying if all the dates are in the same format
#for that first I am importing library
import pandas as pd
from datetime import datetime

# %%
try:
    pd.to_datetime(df['Transaction Date'], format='%Y-%m-%d')
except ValueError:
    print("Dates are not in the same format.")
else:
    print("Dates are in the same format.")
# Out:
# Dates are in the same format.

# %%
# Convert 'Transaction Date' column to datetime
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %%
#verifying if the Transaction Date Column has any null values
has_nulls = df['Transaction Date'].isnull().any()

if has_nulls:
    print("The 'Transaction Date' column contains null values.")
else:
    print("The 'Transaction Date' column does not contain null values.")
# Out:
# The 'Transaction Date' column contains null values.

# %%
# Filling any null values Transaction Date Column has.
df['Transaction Date'] = df['Transaction Date'].fillna(method='ffill') 
df
# Out:
# /var/folders/rf/s1rq5vsn41b15jhqsfjlx44c0000gn/T/ipykernel_42057/781199393.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Transaction Date'] = df['Transaction Date'].fillna(method='ffill')
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# ...

# %%
from datetime import date

days = [
  'Monday',
  'Tuesday',
  'Wednesday',
  'Thursday',
  'Friday',
  'Saturday',
  'Sunday'
  ]

# %%
df['DayoftheWeek']=df['Transaction Date'].dt.strftime("%A")
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date DayoftheWeek
# 0        Credit Card  Takeaway       2023-09-08       Friday
# ...

# %%
import calendar

# %%
df['month']=df['Transaction Date'].dt.month
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date DayoftheWeek  month
# 0        Credit Card  Takeaway       2023-09-08       Friday      9
# ...

# %%
df['Month_name'] = df['month'].apply(lambda x: calendar.month_name[x])

df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date DayoftheWeek  month Month_name
# ...

# %%
#created new columns from Transaction Date namely Month,Month_name and DayOfTheWeek
#To use them for Data Visualization.

# %%
# Create a complete date range
#df.full_date_range = pd.date_range(start=df['Transaction Date'].min(), end=df['Transaction Date'].max())
#df

# %%
#Performing Exploratory Data Analysis for the above Clean dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401   Unknown       3.0             3.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             3.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date DayoftheWeek  month Month_name
# ...

# %%
#changing float format
pd.set_option('display.float_format', lambda x: '%.2F' % x)

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee      2.00            2.00         4.00
# 1       TXN_4977031      Cake      4.00            3.00        12.00
# 2       TXN_4271903    Cookie      4.00            1.00         8.00
# 3       TXN_7034554     Salad      2.00            5.00        10.00
# 4       TXN_3160411    Coffee      2.00            2.00         4.00
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee      2.00            2.00         4.00
# 9996    TXN_9659401   Unknown      3.00            3.00         3.00
# 9997    TXN_5255387    Coffee      4.00            2.00         8.00
# 9998    TXN_7695629    Cookie      3.00            3.00         3.00
# 9999    TXN_6170729  Sandwich      3.00            4.00        12.00
#
#       Payment Method  Location Transaction Date DayoftheWeek  month Month_name
# ...

# %%
df.info()
#Gives high-level info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              10000 non-null  object
#  2   Quantity          10000 non-null  float64
#  3   Price Per Unit    10000 non-null  float64
#  4   Total Spent       10000 non-null  float64
#  5   Payment Method    10000 non-null  object
#  6   Location          10000 non-null  object
#  7   Transaction Date  10000 non-null  datetime64[ns]
#  8   DayoftheWeek      10000 non-null  object
#  9   month             10000 non-null  int32
#  10  Month_name        10000 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(1), object(6)
# memory usage: 820.4+ KB

# %%
df.describe()
#Gives high-level overview of the columns of the dataset
# Out:
#        Quantity  Price Per Unit  Total Spent               Transaction Date  \
# count  10000.00        10000.00     10000.00                          10000
# mean       3.03            2.95         8.88  2023-07-02 00:30:31.680000256
# min        1.00            1.00         1.00            2023-01-01 00:00:00
# 25%        2.00            2.00         4.00            2023-04-01 00:00:00
# 50%        3.00            3.00         8.00            2023-07-02 00:00:00
# 75%        4.00            4.00        12.00            2023-10-02 00:00:00
# max        5.00            5.00        25.00            2023-12-31 00:00:00
# std        1.38            1.24         5.86                            NaN
#
#          month
# count 10000.00
# mean      6.53
# min       1.00
# 25%       4.00
# 50%       7.00
# 75%      10.00
# max      12.00
# std       3.45

# %%
#Verifying if there are any null values 
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# DayoftheWeek        0
# month               0
# Month_name          0
# dtype: int64

# %%
#Verifying how many unique values are there in the dataset
df.nunique()
# Out:
# Transaction ID      10000
# Item                    9
# Quantity                5
# Price Per Unit          6
# Total Spent            17
# Payment Method          4
# Location                3
# Transaction Date      365
# DayoftheWeek            7
# month                  12
# Month_name             12
# dtype: int64

# %%
#Sorting values by month inorder to have better info on Monthly Sales
df=df.sort_values(by="month")
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 7841    TXN_9454387     Salad      2.00            5.00        10.00
# 4622    TXN_2339781  Smoothie      2.00            4.00         8.00
# 1678    TXN_6376630   Unknown      2.00            3.00         6.00
# 5132    TXN_6720290  Smoothie      1.00            4.00         4.00
# 6112    TXN_4359885    Cookie      2.00            1.00         2.00
# ...             ...       ...       ...             ...          ...
# 8658    TXN_7687146    Coffee      1.00            2.00         2.00
# 8655    TXN_1931190    Cookie      3.00            1.00         3.00
# 2970    TXN_2152670       Tea      3.00            1.50         4.50
# 2896    TXN_5118667    Coffee      4.00            2.00         8.00
# 8679    TXN_6217375  Smoothie      5.00            4.00        20.00
#
#       Payment Method  Location Transaction Date DayoftheWeek  month Month_name
# ...

# %%
#Sorting values by month in Descending order inorder to have better info on Monthly Sales
df=df.sort_values(by="month", ascending=False)
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 8679    TXN_6217375  Smoothie      5.00            4.00        20.00
# 7858    TXN_1141405    Cookie      1.00            1.00         1.00
# 4632    TXN_4580084  Sandwich      5.00            4.00         8.00
# 4631    TXN_9024186     Juice      2.00            3.00         6.00
# 4628    TXN_9254064    Coffee      2.00            2.00         4.00
# ...             ...       ...       ...             ...          ...
# 3611    TXN_6234070  Smoothie      2.00            4.00         8.00
# 51      TXN_6342161     Salad      5.00            5.00        25.00
# 1345    TXN_8551432   Unknown      3.00            1.50         6.00
# 3578    TXN_9803409    Cookie      4.00            1.00         4.00
# 7841    TXN_9454387     Salad      2.00            5.00        10.00
#
#      Payment Method  Location Transaction Date DayoftheWeek  month Month_name
# ...

# %%
#Correlation between the columns and tells how closely correalted they are
#df.corr()

# %%
print(df.dtypes)
# Out:
# Transaction ID              object
# Item                        object
# Quantity                   float64
# Price Per Unit             float64
# Total Spent                float64
# Payment Method              object
# Location                    object
# Transaction Date    datetime64[ns]
# DayoftheWeek                object
# month                        int32
# Month_name                  object
# dtype: object

# %%
df['Transaction_ID_string']= str(df['Transaction ID'])
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 8679    TXN_6217375  Smoothie      5.00            4.00        20.00
# 7858    TXN_1141405    Cookie      1.00            1.00         1.00
# 4632    TXN_4580084  Sandwich      5.00            4.00         8.00
# 4631    TXN_9024186     Juice      2.00            3.00         6.00
# 4628    TXN_9254064    Coffee      2.00            2.00         4.00
# ...             ...       ...       ...             ...          ...
# 3611    TXN_6234070  Smoothie      2.00            4.00         8.00
# 51      TXN_6342161     Salad      5.00            5.00        25.00
# 1345    TXN_8551432   Unknown      3.00            1.50         6.00
# 3578    TXN_9803409    Cookie      4.00            1.00         4.00
# 7841    TXN_9454387     Salad      2.00            5.00        10.00
#
#      Payment Method  Location Transaction Date DayoftheWeek  month Month_name  \
# ...

# %%
print(df.dtypes)
# Out:
# Transaction ID                   object
# Item                             object
# Quantity                        float64
# Price Per Unit                  float64
# Total Spent                     float64
# Payment Method                   object
# Location                         object
# Transaction Date         datetime64[ns]
# DayoftheWeek                     object
# month                             int32
# Month_name                       object
# Transaction_ID_string            object
# dtype: object

# %%
#Grouping Columns to start looking at the data a little closer
#Trying to get highest total sales by month
#df = df.groupby('Item').mean()
#Verifying if the Item column has a particular item named Smoothie
df['Item'].str.contains('Smoothie')
# Out:
# 8679     True
# 7858    False
# 4632    False
# 4631    False
# 4628    False
#         ...
# 3611     True
# 51      False
# 1345    False
# 3578    False
# 7841    False
# Name: Item, Length: 10000, dtype: bool

# %%
#This displays all the data in the dataset that has Item as Smoothie
df[df['Item'].str.contains('Smoothie')]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 8679    TXN_6217375  Smoothie      5.00            4.00        20.00
# 4644    TXN_3171673  Smoothie      2.00            4.00         8.00
# 8206    TXN_1602435  Smoothie      1.00            4.00         4.00
# 4716    TXN_7805115  Smoothie      2.00            4.00         8.00
# 6059    TXN_9630958  Smoothie      5.00            3.00        20.00
# ...             ...       ...       ...             ...          ...
# 3825    TXN_2859077  Smoothie      3.00            4.00        12.00
# 3752    TXN_5275315  Smoothie      2.00            4.00         8.00
# 6855    TXN_7278328  Smoothie      1.00            4.00         4.00
# 3648    TXN_1082012  Smoothie      5.00            4.00        20.00
# 3611    TXN_6234070  Smoothie      2.00            4.00         8.00
#
#       Payment Method  Location Transaction Date DayoftheWeek  month  \
# 8679            Cash   Unknown       2023-12-07     Thursday     12
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
#Reversing the columns with rows
#Basically Columns becoming the Index
df2 = df.transpose()
df2
# Out:
#                                                                     8679  \
# Transaction ID                                               TXN_6217375
# Item                                                            Smoothie
# Quantity                                                            5.00
# Price Per Unit                                                      4.00
# Total Spent                                                        20.00
# Payment Method                                                      Cash
# Location                                                         Unknown
# Transaction Date                                     2023-12-07 00:00:00
# DayoftheWeek                                                    Thursday
# month                                                                 12
# Month_name                                                      December
# Transaction_ID_string  8679    TXN_6217375\n7858    TXN_1141405\n4632...
#
# ...

# %%
df2 = df2.transpose()
df2.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date', 'DayoftheWeek',
#        'month', 'Month_name', 'Transaction_ID_string'],
#       dtype='object')

# %%
#Box plot helps determine Outliers in the dataset
#In the dataset the below box is where average lies
#and all the circles above it are Outliers
df.boxplot()
# Out:
# <Axes: >

# %%
#This shows the columns that are having data type as number
df3=df.select_dtypes(include='number')
df3
# Out:
#       Quantity  Price Per Unit  Total Spent  month
# 8679      5.00            4.00        20.00     12
# 7858      1.00            1.00         1.00     12
# 4632      5.00            4.00         8.00     12
# 4631      2.00            3.00         6.00     12
# 4628      2.00            2.00         4.00     12
# ...        ...             ...          ...    ...
# 3611      2.00            4.00         8.00      1
# 51        5.00            5.00        25.00      1
# 1345      3.00            1.50         6.00      1
# 3578      4.00            1.00         4.00      1
# 7841      2.00            5.00        10.00      1
#
# [10000 rows x 4 columns]

# %%
df3.boxplot()
# Out:
# <Axes: >
